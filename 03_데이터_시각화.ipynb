# %% [markdown]
# # matplotlib 을 이용한 단일 차트 그리기

# %% [markdown]
# * library 호출

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# * 문제: x가 1,2,3이고, y가 4,5,6인 그래프를 그리시오.

# %%
x = [1,2,3]
y = [4,5,6]

# %%
plt.figure()
plt.plot(x,y)

# %% [markdown]
# 또는

# %%
plt.plot(x,y)

# %% [markdown]
# - lineplot은 y값만 있으면 그림을 그릴 수 있음
# - 이 때, x의 값은 0,1,2... 순서로 자동 지정됨

# %%
plt.plot(y)

# %% [markdown]
# * linewidth를 이용한 선 굵기 조정

# %%
plt.plot(x,y, linewidth = 10)

# %% [markdown]
# * color를 통한 선 색상 조정

# %%
plt.plot(x,y, color= 'red')

# %% [markdown]
# * maker를 이용한 데이터 위치 표시

# %%
plt.plot(x,y, marker='o')

# %% [markdown]
# * marker 크기 변경

# %%
plt.plot(x, y, marker='o', markersize=10)

# %% [markdown]
# * 선 형태 변경

# %%
plt.plot(x, y, linestyle=':')

# %%
plt.plot(x, y, 'o')

# %%
plt.plot(x, y, 'ro')

# %% [markdown]
# * 그래프 명

# %%
plt.plot(x, y)
plt.title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# * 그래프 명 폰트 크기 변경

# %%
plt.plot(x, y)
plt.title('title', fontsize=20)
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# * x축 명, y축 명

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')

# 크기 바꿀 거면 fontsize option넣기
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# * 그리드 설정 (전체)

# %%
plt.plot(x, y)
plt.grid(True)

# x축만 하고싶으면 axis = 'x' option 추가
# y축만 하고싶으면 axis = 'y' option 추가

# %% [markdown]
# * x 범우, y 범위 설정

# %%
plt.plot(x,y)
plt.xlim([1,2])
plt.ylim([4,5])
# Out:
# (4.0, 5.0)

# %% [markdown]
# * axis를 사용한 범위 설정

# %%
plt.plot(x,y)
plt.axis([1,2,4,5])
# Out:
# (1.0, 2.0, 4.0, 5.0)

# %% [markdown]
# * 눈금 글꼴 크기 변경

# %%
plt.plot(x, y)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 20)
# Out:
# (array([3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# * 그래프에 텍스트 삽입

# %%
plt.plot(x, y)
plt.text(2,5, 'text', fontsize='20')
# Out:
# Text(2, 5, 'text')

# %% [markdown]
# # 여러 데이터를 한 차트에 그리기

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# * 문제 : data1(x: 1,2,3; y: 1,2,3)과 data2(x: 1,2,3; y: 1,4,7)을 그래프로 출력하시오.

# %%
x1 = [1,2,3]
y1 = [1,2,3]
x2 = [1,2,3]
y2 = [1,4,7]

# %%
plt.plot(x1, y1, color='blue')
plt.plot(x2, y2, color='red')

# %% [markdown]
# 또는

# %%
plt.plot(x1, y1, 'b', x2, y2, 'r')
# Out:
# [<matplotlib.lines.Line2D at 0x2196033fca0>,
#  <matplotlib.lines.Line2D at 0x2196033fcd0>]

# %% [markdown]
# * 범례 추가

# %%
x1 = [1,2,3]
y1 = [1,2,3]
x2 = [1,2,3]
y2 = [1,4,7]

# %%
plt.plot(x1, y1, color='blue', label='data1')
plt.plot(x2, y2, color='red', label='data2')
plt.legend()

# %% [markdown]
# 또는

# %%
plt.plot(x1, y1, color='blue', label='data1')
plt.plot(x2, y2, color='red', label='data2')
plt.legend(['data1', 'data2'])

# %% [markdown]
# * 범례 위치 / 크기 설정
# -위치 선정

# %%
plt.plot(x1, y1, color='blue', label='data1')
plt.plot(x2, y2, color='red', label='data2')
plt.legend(['data1', 'data2'], loc='upper right')

# %% [markdown]
# * 범례 폰트 사이즈 변경

# %%
plt.plot(x1, y1, color='blue', label='data1')
plt.plot(x2, y2, color='red', label='data2')
plt.legend(['data1', 'data2'], fontsize = 20)

# %% [markdown]
# * 문제 : data1(x: 1,2,3; y: 1,2,3)과 data2(x: 1,2,3; y: 1,100,200)을 그래프로 출력하시오.

# %%
x1 = [1,2,3]
y1 = [1,2,3]
x2 = [1,2,3]
y2 = [1,100,200]

# %%
plt.plot(x1, y1, color='blue')
plt.plot(x2, y2, color='red')

# %% [markdown]
# # subplot / subplots를 이용한 여러개의 차트 그리기

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# * 문제: data1(x: 1,2,3; y: 1,2,3)과 data2(x: 1,2,3; y: 1,100,200)을 그래프로 출력하시오.

# %%
x1 = [1,2,3]
y1 = [1,2,3]
x2 = [1,2,3]
y2 = [1,100,200]

# %% [markdown]
# * subplot을 이용한 해결
#
# subplot(행의 수, 열의 수, 해당 그래프가 그려질 위치)

# %%
plt.subplot(1,2,1)
plt.plot(x1, y1)
plt.title('data1')

plt.subplot(1,2,2)
plt.plot(x2, y2)
plt.title('data2')
# Out:
# Text(0.5, 1.0, 'data2')

# %%
plt.subplot(2,1,1) # plot 이 (2,1)모양임 
plt.plot(x1, y1)
plt.title('data1')

plt.subplot(2,1,2)
plt.plot(x2, y2)
plt.title('data2')
# Out:
# Text(0.5, 1.0, 'data2')

# %% [markdown]
# * tight_layout을 이용하면 레이아웃이 자동으로 설정됨

# %%
plt.subplot(2,1,1) # plot 이 (2,1)모양임 
plt.plot(x1, y1)
plt.title('data1')

plt.subplot(2,1,2)
plt.plot(x2, y2)
plt.title('data2')
plt.tight_layout()

# %% [markdown]
# * subplots을 이용한 해결

# %%
fig, axe1 = plt.subplots(nrows = 1, ncols = 2)

# %%
fig # 도화지와 같음

# %%
axe1
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
axe1[0].plot(x1, y1, color='blue')

# %%
fig

# %%
axe1[1].plot(x2, y2, color='red')

# %%
fig

# %% [markdown]
# * 문제: data1(x: 1,2,3; y: 1,2,3)과 data2(x: 1,2,3; y: 1,50,200)을 그래프로 출력하시오.

# %%
x1 = [1,2,3]
y1 = [1,2,3]
x2 = [1,2,3]
y2 = [1,50,200]

# %%
fig, axe1 = plt.subplots()

axe2 = axe1.twinx()
axe1.plot(x1, y1, color='red', label='data1')
axe2.plot(x2, y2, color='blue', label='data2')

axe1.set_xlabel('x', fontsize='15')
axe1.set_ylabel('y1', fontsize='15')
axe2.set_ylabel('y2', fontsize='15')
# Out:
# Text(0, 0.5, 'y2')

# %% [markdown]
# * y축을 두 개 가진 차트에서 범례 표시하기

# %%
fig, axe1 = plt.subplots()

axe2 = axe1.twinx()
chart1 = axe1.plot(x1, y1, color='red')
chart2 = axe2.plot(x2, y2, color='blue')

axe1.set_xlabel('x', fontsize=15)
axe1.set_ylabel('y1', fontsize=15)
axe2.set_ylabel('y2', fontsize=15)

chart = chart1 + chart2
axe1.legend(chart, ['data1', 'data2'])

# %% [markdown]
# # load_dataset 을 이용한 데이터 셋 불러오기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# load_dataset 사용법 : sns.load_dataset('데이터셋이름')

# %% [markdown]
# 예제1 : iris

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# - 문제: iris 데이터 셋의 petal_length와 petal_width를 이용하여 산점도를 그리시오.

# %% [markdown]
# matplotlib

# %%
plt.scatter(df['petal_length'], df['petal_width'])

# %% [markdown]
# seaborn

# %%
sns.scatterplot(data = df, x='petal_length', y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# matplotlib와 호환

# %%
sns.scatterplot(data = df, x='petal_length', y='petal_width')
plt.title('iris')
# Out:
# Text(0.5, 1.0, 'iris')

# %% [markdown]
# # barplot을 이용한 막대그래프 그리기

# %%
# %pip install matplotlib -U
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Requirement already satisfied: matplotlib in c:\users\camar\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\camar\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\camar\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\camar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'sudo'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'rm'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family']=['NanumGothic', 'sans-serif']
plt.rcParams['axes.unicode_minus'] = False

import seaborn as sns
import pandas as pd

# %% [markdown]
# - 문제: 다음은 2021년 영화별 관람자 수다. 이를 막대그래프로 표현하시오.

# %%
movie_title = ['크루엘라', '극장판 귀멸의 칼날: 무한열차편', '학교 가는 길']
audience = [664308, 2099131, 20067]

data = {'영화제목' : movie_title, '누적관객' : audience}
df = pd.DataFrame(data)

# %%
df
# Out:
#                영화 제목    누적 관객
# 0               크루엘라   664308
# 1  극장판 귀멸의 칼날: 무한열차편  2099131
# 2            학교 가는 길    20067

# %%
sns.barplot(data = df, x = '영화 제목', y = '누적 관객')
# Out:
# <Axes: xlabel='영화 제목', ylabel='누적 관객'>
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# * 차트 크기 변경

# %%
sns.set(rc={'figure.figsize':(10,5)})

# %%
sns.barplot(data = df, x = '영화 제목', y = '누적 관객')
# Out:
# <Axes: xlabel='영화 제목', ylabel='누적 관객'>
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# * 누적 관객수별로 그리기

# %%
sns.barplot(data = df, x = '영화제목', y = '누적관객',
            order= df.sort_values('누적관객').영화제목) # 영화제목에는 ''가 쓰이지 않음.
# Out:
# <Axes: xlabel='영화제목', ylabel='누적관객'>
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# - ascending 을 이용한 내림차순 정렬

# %%
chart = sns.barplot(data=df, x='영화제목', y='누적관객',
            order=df.sort_values('누적관객', ascending=False).영화제목)

ylabels = ['{:, 0f}'.format(i) + '만 명' for i in chart.get_yticks() / 10000]
chart.set_yticklabels(ylabels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12988\453459855.py in <module>
#       2             order=df.sort_values('누적관객', ascending=False).영화제목)
#       3
# ----> 4 ylabels = ['{:, 0f}'.format(i) + '만 명' for i in chart.get_yticks() / 10000]
#       5 chart.set_yticklabels(ylabels)
#
# ~\AppData\Local\Temp\ipykernel_12988\453459855.py in <listcomp>(.0)
#       2             order=df.sort_values('누적관객', ascending=False).영화제목)
#       3
# ----> 4 ylabels = ['{:, 0f}'.format(i) + '만 명' for i in chart.get_yticks() / 10000]
#       5 chart.set_yticklabels(ylabels)
#
# ValueError: Invalid format specifier
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# * 가로로 그리기

# %%
chart = sns.barplot(data=df, x='누적관객', y='영화제목',
                    order=df.sort_values('누적관객', ascending=False).영화제목)

xlabels = ['{:,.0f}'.format(i) + '만 명' for i in chart.get_xticks() / 10000]
chart.set_xticklabels(xlabels)
# Out:
# C:\Users\camar\AppData\Local\Temp\ipykernel_11492\2642759733.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(xlabels)
# [Text(0.0, 0, '0만 명'),
#  Text(250000.0, 0, '25만 명'),
#  Text(500000.0, 0, '50만 명'),
#  Text(750000.0, 0, '75만 명'),
#  Text(1000000.0, 0, '100만 명'),
#  Text(1250000.0, 0, '125만 명'),
#  Text(1500000.0, 0, '150만 명'),
#  Text(1750000.0, 0, '175만 명'),
#  Text(2000000.0, 0, '200만 명'),
#  Text(2250000.0, 0, '225만 명')]
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   func(*args, **kwargs)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45572 (\N{HANGUL SYLLABLE NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44061 (\N{HANGUL SYLLABLE GAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44537 (\N{HANGUL SYLLABLE GEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44480 (\N{HANGUL SYLLABLE GWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47736 (\N{HANGUL SYLLABLE MYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52860 (\N{HANGUL SYLLABLE KAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54200 (\N{HANGUL SYLLABLE PYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50648 (\N{HANGUL SYLLABLE EL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45716 (\N{HANGUL SYLLABLE NEUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\camar\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# * 색상을 변경하고 싶으면 'color=' 옵션 사용할 것.
# * 폰트 사이즈 변경하고 싶으면 'fontsize=' 옵션 사용할 것
# * 제목 추가 하고 싶으면 'title='옵션 사용할 것

# %% [markdown]
# # countplot 을 이용한 막대그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(10,5)})
import pandas as pd

# %% [markdown]
# * titanic 데이터 셋의 성별 인원수를 시각화 하시오.

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.groupby(by='sex')['sex'].count()
# Out:
# sex
# female    314
# male      577
# Name: sex, dtype: int64

# %% [markdown]
# - countplot 을 이용한 해결

# %%
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# * 가로로 그리고 싶으면 y='sex'

# %% [markdown]
# * 문제: titanic 데이터 셋의 성별 인원수를 객실 등급별로 시각화 하시오.

# %%
df[['sex', 'class']]
# Out:
#         sex   class
# 0      male   Third
# 1    female   First
# 2    female   Third
# 3    female   First
# 4      male   Third
# ..      ...     ...
# 886    male  Second
# 887  female   First
# 888  female   Third
# 889    male   First
# 890    male   Third
#
# [891 rows x 2 columns]

# %%
df.groupby(by=['sex', 'class'])['sex'].count()
# Out:
# sex     class
# female  First      94
#         Second     76
#         Third     144
# male    First     122
#         Second    108
#         Third     347
# Name: sex, dtype: int64

# %%
sns.countplot(data=df, x='sex', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# - palette를 상요한 색상 조정

# %%
sns.countplot(data=df, x='sex', hue='class', palette='flare')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # scatterplot 을 이용한 산점도 그리기

# %%
import matplotlib.pylab as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(10,5)})
import pandas as pd

# %% [markdown]
# * 문제: iris 데이터 셋을 이용하여 sepal_length, sepal_width 별 산점도를 작성하시오.

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.scatterplot(data=df, x='sepal_width', y='sepal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# - hue를 이용한 종 분류

# %%
sns.scatterplot(data=df, x='sepal_width', y='sepal_length', hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# - 추가문제: petal_length의 값을 3 미만, 5 미만, 5 이상으로 표시하여라.

# %%
df['petal_length'].unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
def function(x):
    if x < 3:
        return 's'
    elif 3 <= x < 5:
        return 'm'
    else:
        return 'l'

# %%
df['petal_length2'] = df['petal_length'].apply(function)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species petal_length2
# 0           5.1          3.5           1.4          0.2  setosa             s
# 1           4.9          3.0           1.4          0.2  setosa             s
# 2           4.7          3.2           1.3          0.2  setosa             s
# 3           4.6          3.1           1.5          0.2  setosa             s
# 4           5.0          3.6           1.4          0.2  setosa             s

# %%
sns.scatterplot(data = df, x = 'sepal_width', y = 'sepal_length', hue='species', style='petal_length2')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# - 점의 크기로 분류

# %%
def function2(x):
    if x < 3:
        return 3
    elif 3 <= x < 5:
        return 5
    else:
        return 7

# %%
df['petal_length3'] = df['petal_length'].apply(function2)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species petal_length2  \
# 0           5.1          3.5           1.4          0.2  setosa             s
# 1           4.9          3.0           1.4          0.2  setosa             s
# 2           4.7          3.2           1.3          0.2  setosa             s
# 3           4.6          3.1           1.5          0.2  setosa             s
# 4           5.0          3.6           1.4          0.2  setosa             s
#
#    petal_length3
# 0              3
# 1              3
# 2              3
# 3              3
# 4              3

# %%
sns.scatterplot(data = df, x = 'sepal_width', y = 'sepal_length', hue='species', size='petal_length3')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# - relplot을 이용하면 카테고리 별로 다로 그릴 수 있음.

# %%
sns.relplot(data=df, x='sepal_width', y='sepal_length', col='species')

# %%
sns.lmplot(data = df, x = 'sepal_width', y = 'sepal_length', hue = 'species')

# %% [markdown]
# # linechart 를 이용한 선도표 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(10,5)})
import pandas as pd

# %%
df = sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# - 결측값 확인

# %%
df.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
sns.lineplot(data = df, x = 'year', y = 'passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
